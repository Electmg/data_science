# %% [markdown]
# <center>$\color{green}{\text{0. ПОСТАНОВКА ПРОБЛЕМЫ}}$</center>

# %% [markdown]
# <p style="background: aquamarine;  width:960px; text-align: left; padding: 10px">
# После просмотра документального фильма о сомелье я захотел создать прогностическую модель для оценки вин вслепую, как это делает сомелье.

# %% [markdown]
# <center>$\color{green}{\text{1. СБОР ДАННЫХ}}$</center>

# %% [markdown]
# <p style="background: aquamarine;  width:960px; text-align: left; padding: 10px">
# Определив бизнес-задачу, я перешел к сбору данных для обучения модели. После нескольких недель парсинга сайта WineEnthusiast мне удалось собрать около 130 тысяч строк обзоров вин для анализа и обучения.

# %% [markdown]
# <center>$\color{green}{\text{2. ОЧИСТКА ДАННЫХ}}$</center>

# %% [markdown]
# <p style="background: aquamarine;  width:960px; text-align: left; padding: 10px">
# На данном этапе следует избавиться от «мусора» (некачественных данных), нужно определить пропущенные значения, аномалии и выбросы в данных и именно от этого этапа будет зависеть качество финальной модели машинного обучения.

# %% [markdown]
# <center>$\color{green}{\text{3. РАЗВЕДЫВАТЕЛЬНЫЙ АНАЛИЗ ДАННЫХ}}$</center>

# %% [markdown]
# <p style="background: aquamarine;  width:960px; text-align: left; padding: 10px">
# После сбора и очистки данных, следует искать подсказки и идеи для извлечения из них полезной информации для бизнес-задачи: создание прогностической модели для оценки вин вслепую. На данном этапе нужно исследовать одну переменную, затем две переменные вместе, а затем сразу несколько переменных. Если модель показывает неудовлетворительные результаты, то в большинстве случаев виновником является набор обучающих данных, содержащий ошибки.

# %% [markdown]
# <center>$\color{green}{\text{4. ЭТАП МОДЕЛИРОВАНИЯ И ВЫВОДА МОДЕЛИ В ПРОДАКШЕН }}$</center>

# %% [markdown]
# <p style="background: aquamarine;  width:960px; text-align: left; padding: 10px">
# На этом этапе ведётся построение предсказательных моделей, проверка качества и публикация модели.
# Цикл машинного обучения редко имеет линейную структуру. Он представляют собой повторяющийся цикл улучшения данных и модели.

# %% [markdown]
# **РАЗВЕДЫВАТЕЛЬНЫЙ АНАЛИЗ ДАННЫХ** состоит из следующих этапов:
#
# - **ПРОЕКТИРОВАНИЕ ПРИЗНАКОВ** - это процесс создания новых признаков для повышения качества прогнозной модели. Цель этого метода — создать новые, более сильные признаки для обучения модели.
# - **ОТБОР ПРИЗНАКОВ** - это процесс выбора признаков из общего набора данных признаков, больше всего влияющих на качество модели.
# - **КОДИРОВАНИЯ ПРИЗНАКОВ** - это процесс изменения признаков(в основном категориальных признаков) представленных в строковом формате в численный формат, т.к большинство алгоритмов машинного обучения требуют численный формат.
# - **ПРОВЕРКА СТАТИЧЕСКИХ ГИПОТЕЗ**
