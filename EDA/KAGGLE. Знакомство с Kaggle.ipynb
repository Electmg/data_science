# %% [markdown]
# ## 2. Основы Kaggle

# %% [markdown]
# Kaggle — международная платформа для проведения соревнований по анализу данных на основе реальных задач от различных компаний. Эта площадка может похвастаться самым большим Data Science-комьюнити со всего мира — более 200 тысяч участников, с которыми можно взаимодействовать посредством разных активностей.

# %% [markdown]
# Площадка Kaggle важна для становления дата-сайентиста: работодатели оценивают активность кандидатов и их достижения на площадке. Для обоих участников рынка труда это удобный инструмент: работодатели имеют возможность увидеть, как кандидат пишет код, излагает мысли, что загружает; а работник может использовать площадку как своё портфолио.
#
# Если перейти во вкладку Competitions, можно увидеть список соревнований разных видов.
#
# - Соревнование типа Knowledge. За этот вид соревнований для новичков баллы не начисляются.
# - Соревнования с денежной наградой.
# - Соревнования, привязанные к определённым курсам, мероприятиям и так далее.
#
# Участие в соревнованиях влияет на публичный рейтинг пользователя.

# %% [markdown]
# Рейтинги составляются по четырём видам активностей:
#
# 1. Competitions (участие в соревнованиях);
# 2. Datasets (публикация открытых датасетов);
# 3. Notebooks (создание ноутбуков);
# 4. Discussions (публикация сообщений на форуме).
# Пользователи Kaggle могут последовательно достичь следующих пяти разных уровней статуса в любой из категорий: *Novice, Contributor, Expert, Master и Grandmaster*.

# %% [markdown]
#  <p style="background: aquamarine;  text-align: left; padding: 10px">
# Для достижения каждого из этих уровней требуется выполнить определённые условия, которые усложняются с каждым шагом в сторону Grandmaster. Рейтинги Kaggle важны для карьеры любого дата-сайентиста: на текущий момент почти все работодатели обращают пристальное внимание на успехи кандидата на этой площадке. Как правило, работодатели при просмотре профиля соискателя на Kaggle обращают внимание на уровни в категориях Competitions и Notebooks — именно эти категории позволяют оценить специфические навыки дата-сайентиста.

# %% [markdown]
# 1. Novice (Новичок). Для получения ранга достаточно зарегистрироваться на платформе.
# 2. Contributor (Активный пользователь). Для получения ранга необходимо запустить один ноутбук или скрипт + подать одну заявку на соревнование + оставить один комментарий + один раз проголосовать.
# 3. Expert (Эксперт). Для получения ранга необходимо 2 бронзовых медали в соревнованиях ИЛИ 3 бронзовых медали за датасеты ИЛИ 5 бронзовых медалей за ноутбуки ИЛИ 50 бронзовых медалей за обсуждения.
# 4. Master (Мастер). Для получения ранга необходима 1 золотая медаль + 2 серебряные медали в соревнованиях ИЛИ 1 золотая медаль + 4 серебряных медали за датасеты ИЛИ 10 серебряных медалей за ноутбуки ИЛИ 50 серебряных медалей + 200 медалей в общем за обсуждения.
# 5. Grandmaster (Грандмастер). Для получения ранга необходимо 5 золотых медалей + одна сольная золотая медаль в соревнованиях ИЛИ 5 золотых медалей + 5 серебряных медалей за датасеты ИЛИ 15 золотых медалей за ноутбуки ИЛИ 50 золотых медалей + 500 медалей итого за обсуждения.

# %% [markdown]
# Kaggle показывает прогресс и необходимые действия для повышения своего ранга на домашней странице пользователя в правой области страницы.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# С каждым пользователем можно связаться, нажав на кнопку *Contact User* в правом верхнем углу публичного профиля пользователя. Это может быть необходимо, чтобы объединиться для участия в соревновании или общения. Также можно подписаться на обновления этого пользователя (*Follow User*).

# %% [markdown]
# <center><b>СОРЕВНОВАНИЯ НА KAGGLE

# %% [markdown]
# [Откроем](https://www.kaggle.com/c/hse1-apartmentprice) уже завершённое соревнование на Kaggle и на его примере познакомимся с этим важнейшим элементом площадки.

# %% [markdown]
# На странице каждого соревнования вы увидите несколько вкладок:
#
# - **Overview**. Во вкладке расположена информация с описанием соревнования (Description) и об оценке решения (Evaluation). Обращайте особое внимание на эту информацию: в дальнейшем вы убедитесь, что внимательное отношение к метрикам может значительно изменить итоговую оценку вашего решения!
# - **Data**. Здесь располагаются датасеты к соревнованию. Скачать файлы можно только после согласия с правилами соревнования.
# - **Code**. Здесь находятся ноутбуки и бейзлайны, созданные как вами, так и другими участниками соревнования. Правило хорошего тона — ставить Upvote ноутбукам.
# - **Discussion**. В этом разделе можно принять участие в обсуждении, поблагодарить авторов, задать вопрос и ознакомиться с комментариями сообщества.
# - **Leaderboard**. В этом разделе отображаются результаты сабмитов — публичные и приватные. Очки и медали начисляются за результаты в приватных лидербордах. Обратите внимание на правила расчёта позиций в лидербордах. В этом соревновании позиции в публичном лидерборде рассчитываются по Score, полученному на 50 % тестовой выборки. Поскольку соревнование ещё не завершено, финальный результат будет рассчитан по Score, полученному на оставшейся половине тестовой выборки.
# - **Rules**. Информация о правилах соревнования: можно ли объединяться в команды, какие библиотеки можно использовать и так далее.

# %% [markdown]
# ## 3. Работа с ноутбуками в Kaggle

# %% [markdown]
#  <p style="background: #E1DEDE; border:1px black  solid; text-align: left; padding: 10px">
# → Публикация ноутбуков — один из важных пунктов развития дата-сайентиста на Kaggle. Они позволяют показать сообществу свои идеи относительно конкретного соревнования/датасета и получить обратную связь от сообщества.

# %% [markdown]
# <center>$\color{green}{\text{СОЗДАНИЕ НОУТБУКА KAGGLE}}$</center>

# %% [markdown]
# Чтобы [присоединиться к соревнованию](https://www.kaggle.com/t/06d1ae348e4d448eb1f92e04e5e9eb91), достаточно нажать кнопку Join Competition и согласиться с правилами.
#
# → Во вкладке Overview вы увидите описание задачи и условий соревнования (раздел Description) и информацию о метриках качества решения (раздел Evaluation).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Наше соревнование посвящено предсказанию стоимости автомобиля по его характеристикам, а метрикой качества является MAE (Mean Absolute Error, среднее абсолютное отклонение).
#
# Результаты этого соревнования не будут учитываться в рангах по соревнованиям, но засчитаются по обсуждениям, датасетам и ноутбукам.
#
# →  Вкладка Data содержит в себе информацию о датасетах. В нашем соревновании их три:
# - sample_submission.csv;
# - test_data.csv (данные, на которых мы будем делать предсказание. Не содержат в себе целевую переменную final_price);
# - train_data.csv (обучающая выборка).
#
# →  Во вкладке Code находятся все ноутбуки, которые встречаются в соревновании. В нашем случае это ноутбук с бейзлайном и ноутбук, который нужно будет склонировать для дальнейшей работы.
#
# →  Во вкладке Leaderboard размещена информация о результатах участников соревнования.

# %% [markdown]
# <center><b>КАК СОЗДАТЬ KAGGLE NOTEBOOK?

# %% [markdown]
# Во вкладке Code в правом верхнем углу необходимо нажать на кнопку New Notebook. На открывшейся странице загрузится ноутбук с присвоенным по умолчанию названием.
#
# ![image.png](attachment:image.png)
#
# Ячейки в ноутбуке Kaggle добавляются так же, как и в классическом Jupyter Notebook, сочетанием Shift + Enter или нажатием на кнопку Run Current Cell в панели инструментов.
#
# Сессия запускается автоматически при запуске первой ячейки.
#
# Кнопки остановки и перезапуска сессии находятся в правом верхнем углу рядом со статусом сессии.

# %% [markdown]
# В правой части ноутбука находятся важные вкладки, относящиеся к соревнованию.
#
# →  Во вкладке Data располагается информация о входных и выходных данных. В нашем случае автоматически подтягиваются три датасета.
# ![image.png](attachment:image.png)

# %% [markdown]
# →  Во вкладке Competitions находится информация о соревновании: вашем последнем и лучшем результате и количестве суточных сабмитов.
# ![image.png](attachment:image.png)

# %% [markdown]
# →  Во вкладке Settings располагаются настройки ноутбука, например можно выбрать язык программирования (Python или R). Кроме того, при верифицированном номере телефона Kaggle позволяет использовать GPU/TPU-ускорение и интернет-подключение (например, для импорта библиотек).
# ![image.png](attachment:image.png)

# %% [markdown]
# →  Во вкладке Schedule a notebook run можно запланировать автоматический запуск и сохранение ноутбука. Эта функция может пригодиться, например, если какой-нибудь из датасетов обновляется ежемесячно. Однако в нашем случае это не нужно.
#
# →  Ещё одна важная часть страницы нового ноутбука — кнопка Share, которая позволяет выставить настройки приватности нашего ноутбука, добавить участников команды (с двумя уровнями доступа — чтение и редактирование), теги (для облегчения поиска по тегам) и отключить или включить комментарии.
# ![image.png](attachment:image.png)

# %% [markdown]
# <center><b>КАК СОХРАНИТЬ НОУТБУК?

# %% [markdown]
# Для сохранения ноутбука предназначена кнопка Save Version в правом верхнем углу.
# ![image.png](attachment:image.png)

# %% [markdown]
# Можно создать фиксированную версию под конкретным названием, например Starter. К этой версии впоследствии можно будет вернуться.
#
# Есть два варианта сохранения версии:
#
# - с запуском всех ячеек и сохранением вывода (Save & Run All);
# - быстрое сохранение без запуска (Quick Save).
#
# В первом случае все ячейки ноутбука будут выполняться последовательно до конца или до первой ошибки. Во втором варианте сохранение производится без запуска в том виде, в каком вы написали ноутбук.

# %% [markdown]
# В расширенных настройках (Advanced Settings) можно найти опции для сохранения вывода при быстром сохранении (с опциями: никогда не сохранять, всегда сохранять, сохранить вывод для конкретной версии). Рекомендуем выбрать опцию «Всегда сохранять» (Always save output). Также здесь можно использовать сохранение и запуск с ускорением (доступно при верифицированном номере телефона).
# ![image.png](attachment:image.png)

# %% [markdown]
# После сохранения версии в нижнем левом углу вы увидите окно с перечислением активных событий:

# %% [markdown]
# Ноутбук можно открыть в менеджере просмотров (вьюере): ![image.png](attachment:image.png)

# %% [markdown]
# Перейдя в менеджер просмотров, вы увидите свой ноутбук. Здесь вы можете поставить себе Upvote. При нажатии на три точки слева вы увидите дополнительные действия, которые можно произвести с ноутбуком, например загрузить его на локальный диск. ![image.png](attachment:image.png)

# %% [markdown]
# Также вы можете открыть ноутбук, кликнув на него, и увидеть историю версий. У нас пока всего одна версия: ![image.png](attachment:image.png)

# %% [markdown]
# При нажатии на три точки слева вы увидите дополнительные опции, которые можно произвести с конкретной версией, например назначить её версией по умолчанию.

# %% [markdown]
# <center>$\color{green}{\text{КОЕ-ЧТО ЕЩЁ О НОУТБУКАХ}}$</center>

# %% [markdown]
# Кроме вкладки Notebook есть ещё вкладки Data, Logs, Comments и Settings.
#
# - Во вкладке Data содержится информация о вводе и выводе.
# - Во вкладке Logs регистрируются события, связанные с ноутбуком (запуски и сохранения).
# - Во вкладке Settings можно переименовать ноутбук, изменить настройки его видимости и доступа к нему, выбрать версию по умолчанию, включить или отключить комментарии, поделиться ноутбуком с членами команды.
#
# Вернёмся в наш ноутбук и познакомимся поближе с ячейкой, которую Kaggle подгружает по умолчанию. Например, по умолчанию импортируются библиотеки NumPy и Pandas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# А код ниже выводит все входные файлы ноутбука (в нашем случае это будет список из трёх датасетов соревнования). ![image.png](attachment:image.png)

# %% [markdown]
# Если мы хотим загрузить, к примеру, тренировочные данные, мы можем указать путь к ним через команду **read_csv()**. ![image.png](attachment:image.png)

# %% [markdown]
# <center>$\color{green}{\text{КАК СДЕЛАТЬ SUBMISSION? }}$</center>

# %% [markdown]
# Разберём процесс сабмита на примере тренировочного файла sample_submission.csv. ![image.png](attachment:image.png)

# %% [markdown]
# Предположим, мы решили засабмитить результат по целевой переменной (final_price), равной 2000. Это будет выглядеть следующим образом:![image.png](attachment:image.png)

# %% [markdown]
# После этой операции во вкладке *Data → Output* появится первый сабмит (my_first_submit.csv).
#
# После сохранения версии мы можем послать этот результат на соревнование. Это делается так: перейдя в режим просмотра свежей версии ноутбука, выберите в правой панели *Output → my_first_submit.csv* и нажмите кнопку Submit.![image.png](attachment:image.png)

# %% [markdown]
# Свои сабмиты можно увидеть на странице соревнования при нажатии на ссылку *My Submissions*. Вы увидите список своих сабмитов и их рейтинг (Score).
#
# Кнопка *Submit Predictions* позволяет загрузить свой сабмит с компьютера.

# %% [markdown]
# <center>$\color{green}{\text{КЛОНИРОВАНИЕ НОУТБУКА И РАБОТА В НОУТБУКАХ ДРУГИХ УЧАСТНИКОВ}}$</center>

# %% [markdown]
# Помимо создания ноутбука с нуля, есть и вариант использования ноутбука, созданного другим участником.
#
# 1. Перейдём во вкладку Code на странице соревнования.
# 2. В ней, как мы помним, лежит бейзлайн-решение и ноутбук для клонирования (Clone my notebook).
# 3. Откроем его, не забыв поставить Upvote (это хорошая практика).
# 4. В верхней части экрана мы увидим кнопку Copy & Edit.
# ![image.png](attachment:image.png)

# %% [markdown]
# После нажатия на эту кнопку мы перейдём в привычное окно редактирования ноутбука. Можно переименовать его, изучить содержимое и спокойно вносить свои изменения.
#
# Мы видим, что в ноутбуке импортируются стандартные библиотеки Pandas и NumPy, файлы соревнования, а в качестве сабмита взято среднее значение по выборке.
#
# Далее мы можем сохранить эту версию ноутбука, не забыв указать сохранение вывода (Always save output).

# %% [markdown]
# При клонировании ноутбука остаётся информация о ноутбуке-источнике в верхней информационной части страницы. ![image.png](attachment:image.png)

# %% [markdown]
# <center>$\color{green}{\text{КАК ОТСЛЕЖИВАТЬ SCORE СВОИХ РЕШЕНИЙ?}}$</center>

# %% [markdown]
# Допустим, для сабмита вы решите использовать вместо среднего (mean) медиану (median).
#
# Если вы совершите *Quick Save* с настройкой *Always save output*, при просмотре ноутбука вы увидите два сабмит-файла: mean_submit и median_submit. ![image.png](attachment:image.png)

# %% [markdown]
# На соревнование можно послать любой из существующих сабмитов.
#
# Как видите, использование медианы существенно улучшило Score. ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. Участие в соревновании

# %% [markdown]
# <center>$\color{green}{\text{ВВЕДЕНИЕ В LIGHTAUTOML (LAMA) И ПОДГОТОВИТЕЛЬНЫЙ ЭТАП БЕЙЗЛАЙНА}}$</center>

# %% [markdown]
# → Перейдём к ноутбуку с бейзлайном ([LightAutoML competition baseline](https://www.kaggle.com/alexryzhkov/lightautoml-competition-baseline)).

# %% [markdown]
# Этот бейзлайн построен на основе библиотеки, разработанной в Сбере, — **LightAutoML (LAMA)**. В верхней части ноутбука вы увидите ссылку на [GitHub-репозиторий](https://github.com/sb-ai-lab/LightAutoML) этой библиотеки.
#
# Библиотека позволяет автоматически строить модели машинного обучения для различных задач, например для бинарной классификации, мультиклассовой классификации и регрессии, на табличных данных (в том числе вещественных и категориальных данных, датах, текстах и даже изображениях). Этот инструмент позволяет сосредоточиться на важных задачах машинного обучения — генерации признаков, выборе метрик, определении целевой переменной и так далее.
#
# LAMA не входит в стандартную поставку образа Python на Kaggle, поэтому прежде всего необходимо установить её.

# %%
#!pip install -U lightautoml

# %%
# Standard python libraries
import os
import time

# Essential DS libraries
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import torch

# LightAutoML presets, task and report generation
from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task

# %% [markdown]
# Далее определяем константы (количество потоков, таймаут, имя целевой колонки, размер валидационной выборки и так далее).

# %%
N_THREADS = 4
N_FOLDS = 5
RANDOM_STATE = 42
TEST_SIZE = 0.2
TIMEOUT = 600 # equal to 10 minutes
TARGET_NAME = 'final_price'

# %% [markdown]
# Для максимальной воспроизводимости решения используем команды:

# %%
np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %% [markdown]
# Указываем путь к папке с данными:

# %%
#INPUT_DIR = '../input/sf-dst-predict-car-price/'
INPUT_DIR = 'data/'

# %% [markdown]
# Загружаем тренировочный датасет (в нём будет 15 колонок):

# %%
train_data = pd.read_csv(INPUT_DIR + 'train_data.csv')
print(train_data.shape)
train_data.head()
# Out:
# (35000, 15)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI      Santa FE             Jeep
# 4       4               TOYOTA           CHR             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
# 3           Left wheel           Blue                  Black
# 4           Left wheel          Black                     NaN
#
#                car_vin  car_leather_interior deal_type  final_price
# 0                  NaN                     0  For Sale       3650.0
# 1                  NaN                     0  For Sale       6800.0
# 2   KMHTC6AE3GU293912                      1  For Sale       6300.0
# 3                  NaN                     1  For Sale      14488.0
# 4   JTNKHMBX7K1030253                      1  For Sale       5000.0

# %% [markdown]
# Загружаем тестовый датасет (в нём будет 14 колонок, без колонки с целевой переменной):

# %%
test_data = pd.read_csv(INPUT_DIR + 'test_data.csv')
print(test_data.shape)
test_data.head()
# Out:
# (10697, 14)
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0   35000               TOYOTA         Prius        Hatchback
# 1   35001              HYUNDAI       Elantra            Sedan
# 2   35002                LEXUS        NX 300             Jeep
# 3   35003                LEXUS       CT 200h        Hatchback
# 4   35004               TOYOTA         RAV 4             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           323733          2012            Automatic       4/5
# 1           112000          2013            Tiptronic       4/5
# 2            16920          2018            Automatic       NaN
# 3           302742          2012            Automatic       4/5
# 4             1800          2002               Manual       4/5
#
#            wheels vehicle_color vehicle_interior_color              car_vin  \
# 0    Left wheel           Grey                  Black    JTDKN3DU6C5439638
# 1    Left wheel           Grey                  Black            SURATSHIA
# 2    Left wheel          Brown                     NaN   JTJYARBZ5J2104521
# 3    Left wheel          White                     NaN   JTHKD5BH4C2070945
# 4    Left wheel         Silver                  Black                   NaN
#
#    car_leather_interior deal_type
# 0                     1  For Sale
# 1                     1  For Sale
# 2                     1  For Sale
# 3                     1  For Sale
# 4                     0  For Sale

# %% [markdown]
# Загружаем шаблон сабмита (по количеству строк совпадает с тестовыми данными):

# %%
submission = pd.read_csv(INPUT_DIR + 'sample_submission.csv')
print(submission.shape)
submission.head()
# Out:
# (10697, 2)
#    row_ID  final_price
# 0   35000            0
# 1   35001            0
# 2   35002            0
# 3   35003            0
# 4   35004            0

# %% [markdown]
# Далее в бейзлайне идёт небольшая заготовка для генерации дополнительных признаков.

# %%
# Далее в бейзлайне идёт небольшая заготовка для генерации дополнительных признаков.
#%%time

def create_expert_feats(data):
    pass

create_expert_feats(train_data)
create_expert_feats(test_data)

# %% [markdown]
# Последний пункт подготовительного этапа нашей работы — разбиение на тренировочную (80 %, tr_data) и валидационную (20 %, te_data) выборки.

# %%
# Последний пункт подготовительного этапа нашей работы — разбиение на тренировочную (80 %, tr_data) и валидационную (20 %, te_data) выборки. 
tr_data, te_data = train_test_split(
    train_data, 
    test_size=TEST_SIZE, 
    random_state=RANDOM_STATE
)

print(f'Data splitted. Parts sizes: tr_data = {tr_data.shape}, te_data = {te_data.shape}')

tr_data.head()
# Out:
# Data splitted. Parts sizes: tr_data = (28000, 15), te_data = (7000, 15)
#        row_ID vehicle_manufacturer   vehicle_model vehicle_category  \
# 18788   18788              HYUNDAI        Santa FE             Jeep
# 776       776              HYUNDAI        Santa FE             Jeep
# 480       480                  BMW  X5 XDRIVE35 D              Jeep
# 30078   30078             CHRYSLER             300            Sedan
# 29115   29115               TOYOTA         4Runner             Jeep
#
#        current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 18788           177719          2010            Automatic       4/5
# 776             143166          2011            Automatic       4/5
# 480             149000          2015            Tiptronic       4/5
# 30078           133904          2014            Automatic       4/5
# 29115                0          2018            Automatic       4/5
#
#                wheels vehicle_color vehicle_interior_color car_vin  \
# 18788    Left wheel         Silver                  Black      NaN
# 776      Left wheel           Grey                  Black      NaN
# 480      Left wheel          Black                  Black      NaN
# 30078    Left wheel         Silver                  Black      NaN
# 29115    Left wheel          Black                  Black      NaN
#
#        car_leather_interior deal_type  final_price
# 18788                     1  For Sale       7464.0
# 776                       1  For Sale       5959.0
# 480                       1  For Sale      23900.0
# 30078                     1  For Sale       1750.0
# 29115                     1  For Sale        100.0

# %% [markdown]
# <center>$\color{green}{\text{РЕШЕНИЕ ЗАДАЧИ СОРЕВНОВАНИЯ НА ПРИМЕРЕ БЕЙЗЛАЙНА С БИБЛИОТЕКОЙ LIGHTAUTOML}}$</center>

# %% [markdown]
# Первым делом нам необходимо определить, какую именно задачу нужно решить. Для этого в библиотеке LAMA используется объект **TASK**, который мы определили на подготовительном этапе. Документация к этому объекту доступна по [ссылке](https://github.com/sb-ai-lab/LightAutoML).
#
# В нашем случае мы решаем задачу регрессии (подробнее с регрессией мы познакомимся в следующих модулях). Также указываем метрику.

# %% [markdown]
# В нашем случае мы решаем задачу регрессии (подробнее с регрессией мы познакомимся в следующих модулях). Также указываем метрику.

# %%
task = Task('reg', loss = 'mse', metric = 'mse')

# %% [markdown]
# Далее необходимо указать роли переменных: сказать библиотеке, какая колонка является целевой. Кроме того, укажем на то, что колонку *row_ID* можно опустить.

# %%
# Далее необходимо указать роли переменных: сказать библиотеке, какая колонка является целевой. Кроме того, укажем на то, что колонку row_ID можно опустить.
roles = {
    'target': TARGET_NAME,
    'drop': ['row_ID']
}

# %%
# Наш итоговый код: 
automl = TabularAutoML(
    task = task, 
    timeout = TIMEOUT,
    cpu_limit = N_THREADS,
    reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE}
)

# %%
# Следующий этап — обучение тренировочной выборки.
#%%time 
oof_pred = automl.fit_predict(tr_data, roles = roles, verbose = 1)
# Out:
# [19:32:03] Stdout logging level is INFO.
# [19:32:03] Task: reg
#
# [19:32:03] Start automl preset with listed constraints:
# [19:32:03] - time: 600.00 seconds
# [19:32:03] - CPU: 4 cores
# [19:32:03] - memory: 16 GB
#
# [19:32:03] Train data shape: (28000, 15)
#
# [19:32:15] Layer 1 train process start. Time left 587.28 secs
# [19:32:17] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# [19:32:28] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -5134608829.95118
# [19:32:28] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [19:32:28] Time left 574.86 secs
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# [19:32:29] Selector_LightGBM fitting and predicting completed
# [19:32:31] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\lightautoml\transformers\categorical.py:1029: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cnts = cnts.append(Series([cnts.shape[0] + 1], index=[np.nan]))
# [19:32:40] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -5138632320.141326
# [19:32:40] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [19:32:40] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 96.46 secs
# [19:34:25] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [19:34:25] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [19:34:36] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -5135858601.00097
# [19:34:36] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [19:34:36] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [19:34:50] Fitting Lvl_0_Pipe_1_Mod_2_CatBoost finished. score = -5169141328.236191
# [19:34:50] Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# [19:34:50] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ... Time budget is 269.09 secs
# [19:39:23] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [19:39:23] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# [19:39:37] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -5139854707.834683
# [19:39:37] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [19:39:37] Time left 145.77 secs
#
# [19:39:37] Layer 1 training completed.
#
# [19:39:37] Blending: optimization starts with equal weights and score -5136083064.652361
# [19:39:37] Blending: iteration 0: score = -5132177886.107263, weights = [0.46351174 0.0866286  0.44985965 0.         0.        ]
# [19:39:37] Blending: iteration 1: score = -5131937249.385095, weights = [0.5478241  0.         0.45217595 0.         0.        ]
# [19:39:37] Blending: iteration 2: score = -5131937249.385095, weights = [0.5478241  0.         0.45217595 0.         0.        ]
# [19:39:37] Blending: no score update. Terminated
#
# [19:39:37] Automl preset training completed in 454.70 seconds
#
# [19:39:37] Model description:
# Final prediction for new objects (level 0) =
# 	 0.54782 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 	 0.45218 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM)

# %%
# Можно дополнительно прописать вывод окончательного описания модели:
print(automl.create_model_str_desc())
# Out:
# Final prediction for new objects (level 0) =
# 	 0.54782 * (5 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 	 0.45218 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM)

# %%
# Следующий этап — обучение валидационной выборки. 
#%%time

te_pred = automl.predict(te_data)
print(f'Prediction for te_data:\n{te_pred}\nShape = {te_pred.shape}')
# Out:
# Prediction for te_data:
# array([[8708.837 ],
#        [7258.8813],
#        [2754.8828],
#        ...,
#        [5315.3047],
#        [5660.633 ],
#        [6841.1084]], dtype=float32)
# Shape = (7000, 1)

# %%
# Измеряем качество модели, сравнивая MAE на тренировочной и валидационной выборках:
print(f'TRAIN out-of-fold score: {mean_absolute_error(tr_data[TARGET_NAME].values, oof_pred.data[:, 0])}')
print(f'HOLDOUT score: {mean_absolute_error(te_data[TARGET_NAME].values, te_pred.data[:, 0])}')
# Out:
# TRAIN out-of-fold score: 3829.0370917816163
# HOLDOUT score: 3980.6609957972937

# %% [markdown]
# <center>$\color{green}{\text{ВАЖНОСТЬ ПРИЗНАКОВ МОДЕЛИ, ПОДГОТОВКА САБМИТА С ПОМОЩЬЮ LAMA}}$</center>

# %% [markdown]
# Мы построили модель автоматически, не приложив к этому значительных усилий. Однако нам важно узнать, какие признаки повлияли на полученные предсказания.
#
# В этих целях внутри библиотеки LAMA реализовано несколько методов, например fast и accurate. Эти методы помогают оценить, насколько хорошо или плохо влияет тот или иной признак на построение модели.
#
# **Метод fast** вызовем от автообученной модели *automl*, передавая на вход параметр fast.

# %%
# %%time

# Fast feature importances calculation
fast_fi = automl.get_feature_scores('fast')
fast_fi.set_index('Feature')['Importance'].plot.bar(figsize = (30, 10), grid = True)
# Out:
# CPU times: total: 93.8 ms
# Wall time: 118 ms
# <Axes: xlabel='Feature'>

# %% [markdown]
# Видно, что наибольшее влияние на стоимость оказывает год производства автомобиля. Далее идут пробег, количество дверей, наименование модели и так далее.
#
# Проведём оценку при помощи метода **accurate**.

# %%
# %%time

# Accurate feature importances calculation (Permutation importances) -  can take long time to calculate on bigger datasets
accurate_fi = automl.get_feature_scores('accurate', te_data, silent = False)
# Out:
# CPU times: total: 26 s
# Wall time: 10.9 s

# %%
# Отобразим на графике: 
accurate_fi.set_index('Feature')['Importance'].plot.bar(figsize = (30, 10), grid = True)
# Out:
# <Axes: xlabel='Feature'>

# %% [markdown]
# Порядок признаков поменялся, при этом достаточно важными остались и модель автомобиля, и год производства, и тип коробки передач.
#
# Судя по этим оценкам, результаты модели коррелируют со здравым смыслом.
#
# Следующий этап — **предсказание на тестовых данных**. Для этого снова запускаем функцию automl.predict, передав ей тестовый набор данных test_data.

# %%
test_pred = automl.predict(test_data)
print(f'Prediction for te_data:\n{test_pred}\nShape = {test_pred.shape}')
# Out:
# Prediction for te_data:
# array([[2878.044 ],
#        [6668.0557],
#        [6530.9297],
#        ...,
#        [9886.294 ],
#        [5977.6055],
#        [8061.9062]], dtype=float32)
# Shape = (10697, 1)

# %%
# Готовим сабмит, не сохраняя индекс: 
submission[TARGET_NAME] = test_pred.data[:, 0]
submission.to_csv('lightautoml_tabularautoml.csv', index = False)

# %% [markdown]
# ⭐️ Итак, мы прошли путь от загрузки данных до сохранения сабмита, делегировав рутинную работу по построению модели и преобразованию признаков библиотеке LAMA.
#
# Score этого решения составит 3196, что является достаточно неплохим результатом.

# %% [markdown]
# <center>$\color{green}{\text{РЕЗУЛЬТАТ РАБОТЫ, ПРОВЕРКА КАЧЕСТВА МОДЕЛИ}}$</center>

# %% [markdown]
# Рекомендуется следить за ходом обучения модели. Например, обращайте внимание на следующие строки:![image.png](attachment:image.png)

# %% [markdown]
# Они говорят о том, что превышено время ожидания при вычислениях. Безусловно, LAMA сможет сделать предсказания и в таких обстоятельствах, но оптимальное состояние — отсутствие таких строк. Избежать их можно, увеличив значение timeout в константах.
#
# Проведём проверку качества модели. До этого мы сравнивали обученные модели на тренировочной и валидационной выборках. Сейчас мы хотим сравнить обученную модель изменённого бейзлайна с исходным.
#
# В исходном бейзлайне мы поступили следующим образом:

# %%
print(f'TRAIN out-of-fold score: {mean_absolute_error(tr_data[TARGET_NAME].values, oof_pred.data[:, 0])}')
print(f'HOLDOUT score: {mean_absolute_error(te_data[TARGET_NAME].values, te_pred.data[:, 0])}')
# Out:
# TRAIN out-of-fold score: 3829.0370917816163
# HOLDOUT score: 3980.6609957972937

# %% [markdown]
# Запустим ячейку в изменённом ноутбуке: ![image.png](attachment:image.png)

# %% [markdown]
# Если посмотреть на графики важности признаков, можно заметить, что они почти не изменились и всё так же соответствуют здравому смыслу. Единственное важное различие состоит в том, что на первое место вышел признак VIN-номер автомобиля. Этот признак многосоставной и содержит в себе множество нужной информации об автомобиле.

# %% [markdown]
# Получив предсказание, сохраняем его в сабмит-файл, не забыв внести изменения в название файла.
#
# Сохраняем версию ноутбука, открываем его в менеджере просмотра, переходим на вкладку Data, выбираем сохранённый сабмит в разделе Output и нажимаем на кнопку Submit.
#
# ⭐️ Score нашей модели составил 1868!
